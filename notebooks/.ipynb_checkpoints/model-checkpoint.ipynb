# %%
import pandas as pd
import csv
import requests
import numpy as np
from pycaret.regression import *
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
# Import data and drop columns that are not used.

data = pd.read_csv('2017_2020_data.csv')
data = data.drop(data.columns[0], axis=1)

# %%
# Remove final attributes.
data = data.drop(['lag24', 'tot_solar_mwh', 'tot_wind_mwh'], axis=1)

# %%
# Plot prices for 2017-2021.

figure(figsize=(20, 10), dpi=80)

sns.lineplot(x=data.index, y="LMP", data=data, ci=None)
# Out:
# <AxesSubplot:ylabel='LMP'>

# %%
# Detection of outliers
 
data[data['LMP']>800]
# Out:
#                       Date      LMP  Total_Load  lag48  last_day_LMP  month  \
# 14558  2018-09-03 16:00:00  1100.42    22435.22  36.62       25.4425      9
# 14559  2018-09-03 17:00:00  2406.26    22982.70  34.84       25.4425      9
#
#        day
# 14558    3
# 14559    3

# %%
# Drop outliers.

data = data.drop([14558, 14559]).reset_index(drop=True)

# %%
# Seperate data for training and testing. 

train = data.sample(frac=0.9, random_state=408).reset_index(drop=True)
test = data.drop(train.index).reset_index(drop=True)

# %%
# Setup
# Notice, we are missing a few values in 2020.

setup = setup(data = train, target = 'LMP', fold_shuffle=True)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            23:39:36
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                 Data Type
# Date                 Date
# Total_Load        Numeric
# lag48             Numeric
# last_day_LMP      Numeric
# month         Categorical
# day               Numeric
# LMP                 Label

# %%
# Compare different models, and select top six. 
# Sort by percentage error.

compare = compare_models(sort="MAPE")
# Out:
# <style type="text/css">
# #T_28030 th {
#   text-align: left;
# }
# #T_28030_row0_col0, #T_28030_row1_col0, #T_28030_row1_col1, #T_28030_row1_col2, #T_28030_row1_col3, #T_28030_row1_col4, #T_28030_row1_col5, #T_28030_row1_col6, #T_28030_row2_col0, #T_28030_row2_col1, #T_28030_row2_col2, #T_28030_row2_col3, #T_28030_row2_col4, #T_28030_row2_col5, #T_28030_row2_col6, #T_28030_row3_col0, #T_28030_row3_col1, #T_28030_row3_col2, #T_28030_row3_col3, #T_28030_row3_col4, #T_28030_row3_col5, #T_28030_row3_col6, #T_28030_row4_col0, #T_28030_row4_col1, #T_28030_row4_col2, #T_28030_row4_col3, #T_28030_row4_col4, #T_28030_row4_col5, #T_28030_row4_col6, #T_28030_row5_col0, #T_28030_row5_col1, #T_28030_row5_col2, #T_28030_row5_col3, #T_28030_row5_col4, #T_28030_row5_col5, #T_28030_row5_col6, #T_28030_row6_col0, #T_28030_row6_col1, #T_28030_row6_col2, #T_28030_row6_col3, #T_28030_row6_col4, #T_28030_row6_col5, #T_28030_row6_col6, #T_28030_row7_col0, #T_28030_row7_col1, #T_28030_row7_col2, #T_28030_row7_col3, #T_28030_row7_col4, #T_28030_row7_col5, #T_28030_row7_col6, #T_28030_row8_col0, #T_28030_row8_col1, #T_28030_row8_col2, #T_28030_row8_col3, #T_28030_row8_col4, #T_28030_row8_col5, #T_28030_row8_col6, #T_28030_row9_col0, #T_28030_row9_col1, #T_28030_row9_col2, #T_28030_row9_col3, #T_28030_row9_col4, #T_28030_row9_col5, #T_28030_row9_col6, #T_28030_row10_col0, #T_28030_row10_col1, #T_28030_row10_col2, #T_28030_row10_col3, #T_28030_row10_col4, #T_28030_row10_col5, #T_28030_row10_col6, #T_28030_row11_col0, #T_28030_row11_col1, #T_28030_row11_col2, #T_28030_row11_col3, #T_28030_row11_col4, #T_28030_row11_col5, #T_28030_row11_col6, #T_28030_row12_col0, #T_28030_row12_col1, #T_28030_row12_col2, #T_28030_row12_col3, #T_28030_row12_col4, #T_28030_row12_col5, #T_28030_row12_col6, #T_28030_row13_col0, #T_28030_row13_col1, #T_28030_row13_col2, #T_28030_row13_col3, #T_28030_row13_col4, #T_28030_row13_col5, #T_28030_row13_col6, #T_28030_row14_col0, #T_28030_row14_col1, #T_28030_row14_col2, #T_28030_row14_col3, #T_28030_row14_col4, #T_28030_row14_col5, #T_28030_row14_col6, #T_28030_row15_col0, #T_28030_row15_col1, #T_28030_row15_col2, #T_28030_row15_col3, #T_28030_row15_col4, #T_28030_row15_col5, #T_28030_row15_col6, #T_28030_row16_col0, #T_28030_row16_col1, #T_28030_row16_col2, #T_28030_row16_col3, #T_28030_row16_col4, #T_28030_row16_col5, #T_28030_row16_col6, #T_28030_row17_col0, #T_28030_row17_col1, #T_28030_row17_col2, #T_28030_row17_col3, #T_28030_row17_col4, #T_28030_row17_col5, #T_28030_row17_col6, #T_28030_row18_col0, #T_28030_row18_col1, #T_28030_row18_col2, #T_28030_row18_col3, #T_28030_row18_col4, #T_28030_row18_col5, #T_28030_row18_col6 {
#   text-align: left;
# }
# #T_28030_row0_col1, #T_28030_row0_col2, #T_28030_row0_col3, #T_28030_row0_col4, #T_28030_row0_col5, #T_28030_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_28030_row0_col7, #T_28030_row1_col7, #T_28030_row2_col7, #T_28030_row3_col7, #T_28030_row4_col7, #T_28030_row5_col7, #T_28030_row6_col7, #T_28030_row7_col7, #T_28030_row8_col7, #T_28030_row9_col7, #T_28030_row10_col7, #T_28030_row11_col7, #T_28030_row12_col7, #T_28030_row13_col7, #T_28030_row14_col7, #T_28030_row15_col7, #T_28030_row16_col7, #T_28030_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_28030_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_28030">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28030_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_28030_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_28030_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_28030_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_28030_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_28030_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_28030_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_28030_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28030_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_28030_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_28030_row0_col1" class="data row0 col1" >7.5905</td>
#       <td id="T_28030_row0_col2" class="data row0 col2" >226.1101</td>
#       <td id="T_28030_row0_col3" class="data row0 col3" >14.9654</td>
#       <td id="T_28030_row0_col4" class="data row0 col4" >0.7291</td>
#       <td id="T_28030_row0_col5" class="data row0 col5" >0.3242</td>
#       <td id="T_28030_row0_col6" class="data row0 col6" >0.6356</td>
#       <td id="T_28030_row0_col7" class="data row0 col7" >4.4070</td>
#     </tr>
#     <tr>
#       <th id="T_28030_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_28030_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_28030_row1_col1" class="data row1 col1" >7.9879</td>
#       <td id="T_28030_row1_col2" class="data row1 col2" >226.6924</td>
#       <td id="T_28030_row1_col3" class="data row1 col3" >14.9949</td>
#       <td id="T_28030_row1_col4" class="data row1 col4" >0.7283</td>
#       <td id="T_28030_row1_col5" class="data row1 col5" >0.3322</td>
#       <td id="T_28030_row1_col6" class="data row1 col6" >0.6865</td>
#       <td id="T_28030_row1_col7" class="data row1 col7" >5.3710</td>
#     </tr>
#     <tr>
#       <th id="T_28030_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_28030_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_28030_row2_col1" class="data row2 col1" >8.7752</td>
#       <td id="T_28030_row2_col2" class="data row2 col2" >246.3085</td>
#       <td id="T_28030_row2_col3" class="data row2 col3" >15.6282</td>
#       <td id="T_28030_row2_col4" class="data row2 col4" >0.7051</td>
#       <td id="T_28030_row2_col5" class="data row2 col5" >0.3524</td>
#       <td id="T_28030_row2_col6" class="data row2 col6" >0.6871</td>
#       <td id="T_28030_row2_col7" class="data row2 col7" >2.4670</td>
#     </tr>
#     <tr>
#       <th id="T_28030_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_28030_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_28030_row3_col1" class="data row3 col1" >10.7903</td>
#       <td id="T_28030_row3_col2" class="data row3 col2" >435.8934</td>
#       <td id="T_28030_row3_col3" class="data row3 col3" >20.8137</td>
#       <td id="T_28030_row3_col4" class="data row3 col4" >0.4769</td>
#       <td id="T_28030_row3_col5" class="data row3 col5" >0.4509</td>
#       <td id="T_28030_row3_col6" class="data row3 col6" >0.7459</td>
#       <td id="T_28030_row3_col7" class="data row3 col7" >0.4490</td>
#     </tr>
#     <tr>
#       <th id="T_28030_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_28030_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#       <td id="T_28030_row4_col1" class="data row4 col1" >8.7900</td>
#       <td id="T_28030_row4_col2" class="data row4 col2" >241.2099</td>
#       <td id="T_28030_row4_col3" class="data row4 col3" >15.4531</td>
#       <td id="T_28030_row4_col4" class="data row4 col4" >0.7114</td>
#       <td id="T_28030_row4_col5" class="data row4 col5" >0.3508</td>
#       <td id="T_28030_row4_col6" class="data row4 col6" >0.7895</td>
#       <td id="T_28030_row4_col7" class="data row4 col7" >1.4250</td>
#     </tr>
#     <tr>
#       <th id="T_28030_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_28030_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_28030_row5_col1" class="data row5 col1" >9.2468</td>
#       <td id="T_28030_row5_col2" class="data row5 col2" >266.4876</td>
#       <td id="T_28030_row5_col3" class="data row5 col3" >16.2693</td>
#       <td id="T_28030_row5_col4" class="data row5 col4" >0.6804</td>
#       <td id="T_28030_row5_col5" class="data row5 col5" >0.366

# %%
model_et = create_model('et')
# Out:
# <style type="text/css">
# #T_915e3_row10_col0, #T_915e3_row10_col1, #T_915e3_row10_col2, #T_915e3_row10_col3, #T_915e3_row10_col4, #T_915e3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_915e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_915e3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_915e3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_915e3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_915e3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_915e3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_915e3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_915e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_915e3_row0_col0" class="data row0 col0" >7.6222</td>
#       <td id="T_915e3_row0_col1" class="data row0 col1" >185.1187</td>
#       <td id="T_915e3_row0_col2" class="data row0 col2" >13.6058</td>
#       <td id="T_915e3_row0_col3" class="data row0 col3" >0.7608</td>
#       <td id="T_915e3_row0_col4" class="data row0 col4" >0.3388</td>
#       <td id="T_915e3_row0_col5" class="data row0 col5" >1.3918</td>
#     </tr>
#     <tr>
#       <th id="T_915e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_915e3_row7_col0" class="data row7 col0" >7.6644</td>
#       <td id="T_915e3_row7_col1" class="data row7 col1" >201.0497</td>
#       <td id="T_915e3_row7_col2" class="data row7 col2" >14.1792</td>
#       <td id="T_915e3_row7_col3" class="data row7 col3" >0.7500</td>
#       <td id="T_915e3_row7_col4" class="data row7 col4" >0.3212</td>
#       <td id="T_915e3_row7_col5" class="data row7 col5" >0.2977</td>
#     </tr>
#     <tr>
#       <th id="T_915e3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_915e3_row8_col0" class="data row8 col0" >7.5902</td>
#       <td id="T_915e3_row8_col1" class="data row8 col1" >252.4712</td>
#       <td id="T_915e3_row8_col2" class="data row8 col2" >15.8893</td>
#       <td id="T_915e3_row8_col3" class="data row8 col3" >0.7143</td>
#       <td id="T_915e3_row8_col4" class="data row8 col4" >0.3255</td>
#       <td id="T_915e3_row8_col5" class="data row8 col5" >0.2859</td>
#     </tr>
#     <tr>
#       <th id="T_915e3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_915e3_row9_col0" class="data row9 col0" >7.6922</td>
#       <td id="T_915e3_row9_col1" class="data row9 col1" >266.5634</td>
#       <td id="T_915e3_row9_col2" class="data row9 col2" >16.3268</td>
#       <td id="T_915e3_row9_col3" class="data row9 col3" >0.6708</td>
#       <td id="T_915e3_row9_col4" class="data row9 col4" >0.3241</td>
#       <td id="T_915e3_row9_col5" class="data row9 col5" >0.5827</td>
#     </tr>
#     <tr>
#       <th id="T_915e3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_915e3_row10_col0" class="data row10 col0" >7.5905</td>
#       <td id="T_915e3_row10_col1" class="data row10 col1" >226.1101</td>
#       <td id="T_915e3_row10_col2" class="data row10 col2" >14.9654</td>
#       <td id="T_915e3_row10_col3" class="data row10 col3" >0.7291</td>
#       <td id="T_915e3_row10_col4" class="data row10 col4" >0.3242</td>
#       <td id="T_915e3_row10_col5" class="data row10 col5" >0.6356</td>
#     </tr>
#     <tr>
#       <th id="T_915e3_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_915e3_row11_col0" class="data row11 col0" >0.1545</td>
#       <td id="T_915e3_row11_col1" class="data row11 col1" >45.3325</td>
#       <td id="T_915e3_row11_col2" class="data row11 col2" >1.4651</td>
#       <td id="T_915e3_row11_col3" class="data row11 col3" >0.0423</td>
#       <td id="T_915e3_row11_col4" class="data row11 col4" >0.0057</td>
#       <td id="T_915e3_row11_col5" class="data row11 col5" >0.4810</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_8664c_row10_col0, #T_8664c_row10_col1, #T_8664c_row10_col2, #T_8664c_row10_col3, #T_8664c_row10_col4, #T_8664c_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8664c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8664c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8664c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8664c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8664c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8664c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8664c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8664c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8664c_row0_col0" class="data row0 col0" >7.9156</td>
#       <td id="T_8664c_row0_col1" class="data row0 col1" >195.0636</td>
#       <td id="T_8664c_row0_col2" class="data row0 col2" >13.9665</td>
#       <td id="T_8664c_row0_col3" class="data row0 col3" >0.7480</td>
#       <td id="T_8664c_row0_col4" class="data row0 col4" >0.3354</td>
#       <td id="T_8664c_row0_col5" class="data row0 col5" >1.5818</td>
#     </tr>
#     <tr>
#       <th id="T_8664c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_58c89_row9_col0" class="data row9 col0" >8.6855</td>
#       <td id="T_58c89_row9_col1" class="data row9 col1" >234.2447</td>
#       <td id="T_58c89_row9_col2" class="data row9 col2" >15.3051</td>
#       <td id="T_58c89_row9_col3" class="data row9 col3" >0.7107</td>
#       <td id="T_58c89_row9_col4" class="data row9 col4" >0.3511</td>
#       <td id="T_58c89_row9_col5" class="data row9 col5" >1.0025</td>
#     </tr>
#     <tr>
#       <th id="T_58c89_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_58c89_row10_col0" class="data row10 col0" >8.7752</td>
#       <td id="T_58c89_row10_col1" class="data row10 col1" >246.3085</td>
#       <td id="T_58c89_row10_col2" class="data row10 col2" >15.6282</td>
#       <td id="T_58c89_row10_col3" class="data row10 col3" >0.7051</td>
#       <td id="T_58c89_row10_col4" class="data row10 col4" >0.3524</td>
#       <td id="T_58c89_row10_col5" class="data row10 col5" >0.6871</td>
#     </tr>
#     <tr>
#       <th id="T_58c89_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_58c89_row11_col0" class="data row11 col0" >0.1090</td>
#       <td id="T_58c89_row11_col1" class="data row11 col1" >47.2759</td>
#       <td id="T_58c89_row11_col2" class="data row11 col2" >1.4376</td>
#       <td id="T_58c89_row11_col3" class="data row11 col3" >0.0408</td>
#       <td id="T_58c89_row11_col4" class="data row11 col4" >0.0026</td>
#       <td id="T_58c89_row11_col5" class="data row11 col5" >0.4350</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_catboost = create_model('catboost')
# Out:
# <style type="text/css">
# #T_82d67_row10_col0, #T_82d67_row10_col1, #T_82d67_row10_col2, #T_82d67_row10_col3, #T_82d67_row10_col4, #T_82d67_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_82d67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82d67_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_82d67_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_82d67_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_82d67_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_82d67_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_82d67_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82d67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82d67_row0_col0" class="data row0 col0" >8.7167</td>
#       <td id="T_82d67_row0_col1" class="data row0 col1" >198.6265</td>
#       <td id="T_82d67_row0_col2" class="data row0 col2" >14.0935</td>
#       <td id="T_82d67_row0_col3" class="data row0 col3" >0.7434</td>
#       <td id="T_82d67_row0_col4" class="data row0 col4" >0.3658</td>
#       <td id="T_82d67_row0_col5" class="data row0 col5" >1.9733</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82d67_row1_col0" class="data row1 col0" >8.6651</td>
#       <td id="T_82d67_row1_col1" class="data row1 col1" >218.7288</td>
#       <td id="T_82d67_row1_col2" class="data row1 col2" >14.7895</td>
#       <td id="T_82d67_row1_col3" class="data row1 col3" >0.7286</td>
#       <td id="T_82d67_row1_col4" class="data row1 col4" >0.3451</td>
#       <td id="T_82d67_row1_col5" class="data row1 col5" >0.3189</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_82d67_row2_col0" class="data row2 col0" >8.9056</td>
#       <td id="T_82d67_row2_col1" class="data row2 col1" >290.3686</td>
#       <td id="T_82d67_row2_col2" class="data row2 col2" >17.0402</td>
#       <td id="T_82d67_row2_col3" class="data row2 col3" >0.6351</td>
#       <td id="T_82d67_row2_col4" class="data row2 col4" >0.3539</td>
#       <td id="T_82d67_row2_col5" class="data row2 col5" >0.3469</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_82d67_row3_col0" class="data row3 col0" >8.6082</td>
#       <td id="T_82d67_row3_col1" class="data row3 col1" >196.0657</td>
#       <td id="T_82d67_row3_col2" class="data row3 col2" >14.0023</td>
#       <td id="T_82d67_row3_col3" class="data row3 col3" >0.7685</td>
#       <td id="T_82d67_row3_col4" class="data row3 col4" >0.3528</td>
#       <td id="T_82d67_row3_col5" class="data row3 col5" >0.4255</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_82d67_row4_col0" class="data row4 col0" >8.6612</td>
#       <td id="T_82d67_row4_col1" class="data row4 col1" >198.2041</td>
#       <td id="T_82d67_row4_col2" class="data row4 col2" >14.0785</td>
#       <td id="T_82d67_row4_col3" class="data row4 col3" >0.7428</td>
#       <td id="T_82d67_row4_col4" class="data row4 col4" >0.3464</td>
#       <td id="T_82d67_row4_col5" class="data row4 col5" >1.8182</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_82d67_row5_col0" class="data row5 col0" >9.1036</td>
#       <td id="T_82d67_row5_col1" class="data row5 col1" >362.1419</td>
#       <td id="T_82d67_row5_col2" class="data row5 col2" >19.0300</td>
#       <td id="T_82d67_row5_col3" class="data row5 col3" >0.6259</td>
#       <td id="T_82d67_row5_col4" class="data row5 col4" >0.3523</td>
#       <td id="T_82d67_row5_col5" class="data row5 col5" >0.9916</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_82d67_row6_col0" class="data row6 col0" >8.8054</td>
#       <td id="T_82d67_row6_col1" class="data row6 col1" >226.4575</td>
#       <td id="T_82d67_row6_col2" class="data row6 col2" >15.0485</td>
#       <td id="T_82d67_row6_col3" class="data row6 col3" >0.7335</td>
#       <td id="T_82d67_row6_col4" class="data row6 col4" >0.3529</td>
#       <td id="T_82d67_row6_col5" class="data row6 col5" >0.3501</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_82d67_row7_col0" class="data row7 col0" >8.9146</td>
#       <td id="T_82d67_row7_col1" class="data row7 col1" >220.5491</td>
#       <td id="T_82d67_row7_col2" class="data row7 col2" >14.8509</td>
#       <td id="T_82d67_row7_col3" class="data row7 col3" >0.7258</td>
#       <td id="T_82d67_row7_col4" class="data row7 col4" >0.3432</td>
#       <td id="T_82d67_row7_col5" class="data row7 col5" >0.3465</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_82d67_row8_col0" class="data row8 col0" >8.7918</td>
#       <td id="T_82d67_row8_col1" class="data row8 col1" >280.0455</td>
#       <td id="T_82d67_row8_col2" class="data row8 col2" >16.7346</td>
#       <td id="T_82d67_row8_col3" class="data row8 col3" >0.6831</td>
#       <td id="T_82d67_row8_col4" class="data row8 col4" >0.3484</td>
#       <td id="T_82d67_row8_col5" class="data row8 col5" >0.3335</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_82d67_row9_col0" class="data row9 col0" >8.7274</td>
#       <td id="T_82d67_row9_col1" class="data row9 col1" >220.9112</td>
#       <td id="T_82d67_row9_col2" class="data row9 col2" >14.8631</td>
#       <td id="T_82d67_row9_col3" class="data row9 col3" >0.7271</td>
#       <td id="T_82d67_row9_col4" class="data row9 col4" >0.3475</td>
#       <td id="T_82d67_row9_col5" class="data row9 col5" >0.9904</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_82d67_row10_col0" class="data row10 col0" >8.7900</td>
#       <td id="T_82d67_row10_col1" class="data row10 col1" >241.2099</td>
#       <td id="T_82d67_row10_col2" class="data row10 col2" >15.4531</td>
#       <td id="T_82d67_row10_col3" class="data row10 col3" >0.7114</td>
#       <td id="T_82d67_row10_col4" class="data row10 col4" >0.3508</td>
#       <td id="T_82d67_row10_col5" class="data row10 col5" >0.7895</td>
#     </tr>
#     <tr>
#       <th id="T_82d67_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_82d67_row11_col0" class="data row11 col0" >0.1421</td>
#       <td id="T_82d67_row11_col1" class="data row11 col1" >50.8056</td>
#       <td id="T_82d67_row11_col2" class="data row11 col2" >1.5528</td>
#       <td id="T_82d67_row11_col3" class="data row11 col3" >0.0452</td>
#       <td id="T_82d67_row11_col4" class="data row11 col4" >0.0061</td>
#       <td id="T_82d67_row11_col5" class="data row11 col5" >0.6073</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_41aac_row10_col0, #T_41aac_row10_col1, #T_41aac_row10_col2, #T_41aac_row10_col3, #T_41aac_row10_col4, #T_41aac_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_41aac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41aac_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_41aac_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_41aac_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_41aac_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_41aac_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_41aac_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41aac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41aac_row0_col0" class="data row0 col0" >9.2664</td>
#       <td id="T_41aac_row0_col1" class="data row0 col1" >235.6154</td>
#       <td id="T_41aac_row0_col2" class="data row0 col2" >15.3498</td>
#       <td id="T_41aac_row0_col3" class="data row0 col3" >0.6956</td>
#       <td id="T_41aac_row0_col4" class="data row0 col4" >0.3777</td>
#       <td id="T_41aac_row0_col5" class="data row0 col5" >2.0807</td>
#     </tr>
#     <tr>
#       <th id="T_41aac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41aac_row1_col0" class="data row1 col0" >9.0802</td>
#       <td id="T_41aac_row1_col1" class="data row1 col1" >246.7624</td>
#       <td id="T_41aac_row1_col2" class="data row1 col2" >15.7087</td>
#       <td id="T_41aac_row1_col3" class="data row1 col3" >0.6938</td>
#       <td id="T_41aac_row1_col4" class="data row1 col4" >0.3632</td>
#       <td id="T_41aac_row1_col5" class="data row1 col5" >0.3407</td>
#     </tr>
#     <tr>
#       <th id="T_41aac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41aac_row2_col0" class="data row2 col0" >9.3976</td>
#       <td id="T_41aac_row2_col1" class="data row2 col1" >313.6334</td>
#       <td id="T_41aac_row2_col2" class="data row2 col2" >17.7097</td>
#       <td id="T_41aac_row2_col3" class="data row2 col3" >0.6058</td>
#       <td id="T_41aac_row2_col4" class="data row2 col4" >0.3694</td>
#       <td id="T_41aac_row2_col5" class="data row2 col5" >0.3750</td>
#     </tr>
#     <tr>
#       <th id="T_41aac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T
level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_41aac_row10_col0" class="data row10 col0" >9.2468</td>
#       <td id="T_41aac_row10_col1" class="data row10 col1" >266.4876</td>
#       <td id="T_41aac_row10_col2" class="data row10 col2" >16.2693</td>
#       <td id="T_41aac_row10_col3" class="data row10 col3" >0.6804</td>
#       <td id="T_41aac_row10_col4" class="data row10 col4" >0.3664</td>
#       <td id="T_41aac_row10_col5" class="data row10 col5" >0.8557</td>
#     </tr>
#     <tr>
#       <th id="T_41aac_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_41aac_row11_col0" class="data row11 col0" >0.1633</td>
#       <td id="T_41aac_row11_col1" class="data row11 col1" >45.8013</td>
#       <td id="T_41aac_row11_col2" class="data row11 col2" >1.3409</td>
#       <td id="T_41aac_row11_col3" class="data row11 col3" >0.0400</td>
#       <td id="T_41aac_row11_col4" class="data row11 col4" >0.0046</td>
#       <td id="T_41aac_row11_col5" class="data row11 col5" >0.6697</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_be70f_row10_col0, #T_be70f_row10_col1, #T_be70f_row10_col2, #T_be70f_row10_col3, #T_be70f_row10_col4, #T_be70f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_be70f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be70f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_be70f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_be70f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_be70f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_be70f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_be70f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be70f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be70f_row0_col0" class="data row0 col0" >10.4845</td>
#       <td id="T_be70f_row0_col1" class="data row0 col1" >340.1316</td>
#       <td id="T_be70f_row0_col2" class="data row0 col2" >18.4427</td>
#       <td id="T_be70f_row0_col3" class="data row0 col3" >0.5605</td>
#       <td id="T_be70f_row0_col4" class="data row0 col4" >0.4610</td>
#       <td id="T_be70f_row0_col5" class="data row0 col5" >1.6634</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be70f_row1_col0" class="data row1 col0" >10.6795</td>
#       <td id="T_be70f_row1_col1" class="data row1 col1" >389.4241</td>
#       <td id="T_be70f_row1_col2" class="data row1 col2" >19.7338</td>
#       <td id="T_be70f_row1_col3" class="data row1 col3" >0.5167</td>
#       <td id="T_be70f_row1_col4" class="data row1 col4" >0.4449</td>
#       <td id="T_be70f_row1_col5" class="data row1 col5" >0.3705</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be70f_row2_col0" class="data row2 col0" >10.8331</td>
#       <td id="T_be70f_row2_col1" class="data row2 col1" >479.4896</td>
#       <td id="T_be70f_row2_col2" class="data row2 col2" >21.8973</td>
#       <td id="T_be70f_row2_col3" class="data row2 col3" >0.3974</td>
#       <td id="T_be70f_row2_col4" class="data row2 col4" >0.4446</td>
#       <td id="T_be70f_row2_col5" class="data row2 col5" >0.4056</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be70f_row3_col0" class="data row3 col0" >10.7428</td>
#       <td id="T_be70f_row3_col1" class="data row3 col1" >393.6496</td>
#       <td id="T_be70f_row3_col2" class="data row3 col2" >19.8406</td>
#       <td id="T_be70f_row3_col3" class="data row3 col3" >0.5352</td>
#       <td id="T_be70f_row3_col4" class="data row3 col4" >0.4448</td>
#       <td id="T_be70f_row3_col5" class="data row3 col5" >0.4533</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be70f_row4_col0" class="data row4 col0" >10.4862</td>
#       <td id="T_be70f_row4_col1" class="data row4 col1" >357.5161</td>
#       <td id="T_be70f_row4_col2" class="data row4 col2" >18.9081</td>
#       <td id="T_be70f_row4_col3" class="data row4 col3" >0.5361</td>
#       <td id="T_be70f_row4_col4" class="data row4 col4" >0.4383</td>
#       <td id="T_be70f_row4_col5" class="data row4 col5" >1.7720</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be70f_row5_col0" class="data row5 col0" >11.1096</td>
#       <td id="T_be70f_row5_col1" class="data row5 col1" >546.1855</td>
#       <td id="T_be70f_row5_col2" class="data row5 col2" >23.3706</td>
#       <td id="T_be70f_row5_col3" class="data row5 col3" >0.4357</td>
#       <td id="T_be70f_row5_col4" class="data row5 col4" >0.4474</td>
#       <td id="T_be70f_row5_col5" class="data row5 col5" >1.1121</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be70f_row6_col0" class="data row6 col0" >11.2860</td>
#       <td id="T_be70f_row6_col1" class="data row6 col1" >545.7474</td>
#       <td id="T_be70f_row6_col2" class="data row6 col2" >23.3612</td>
#       <td id="T_be70f_row6_col3" class="data row6 col3" >0.3577</td>
#       <td id="T_be70f_row6_col4" class="data row6 col4" >0.4617</td>
#       <td id="T_be70f_row6_col5" class="data row6 col5" >0.4112</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be70f_row7_col0" class="data row7 col0" >10.9622</td>
#       <td id="T_be70f_row7_col1" class="data row7 col1" >397.8771</td>
#       <td id="T_be70f_row7_col2" class="data row7 col2" >19.9469</td>
#       <td id="T_be70f_row7_col3" class="data row7 col3" >0.5052</td>
#       <td id="T_be70f_row7_col4" class="data row7 col4" >0.4537</td>
#       <td id="T_be70f_row7_col5" class="data row7 col5" >0.3975</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be70f_row8_col0" class="data row8 col0" >10.5372</td>
#       <td id="T_be70f_row8_col1" class="data row8 col1" >450.7287</td>
#       <td id="T_be70f_row8_col2" class="data row8 col2" >21.2304</td>
#       <td id="T_be70f_row8_col3" class="data row8 col3" >0.4899</td>
#       <td id="T_be70f_row8_col4" class="data row8 col4" >0.4477</td>
#       <td id="T_be70f_row8_col5" class="data row8 col5" >0.3635</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be70f_row9_col0" class="data row9 col0" >10.7823</td>
#       <td id="T_be70f_row9_col1" class="data row9 col1" >458.1844</td>
#       <td id="T_be70f_row9_col2" class="data row9 col2" >21.4052</td>
#       <td id="T_be70f_row9_col3" class="data row9 col3" >0.4341</td>
#       <td id="T_be70f_row9_col4" class="data row9 col4" >0.4648</td>
#       <td id="T_be70f_row9_col5" class="data row9 col5" >0.5099</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_be70f_row10_col0" class="data row10 col0" >10.7903</td>
#       <td id="T_be70f_row10_col1" class="data row10 col1" >435.8934</td>
#       <td id="T_be70f_row10_col2" class="data row10 col2" >20.8137</td>
#       <td id="T_be70f_row10_col3" class="data row10 col3" >0.4769</td>
#       <td id="T_be70f_row10_col4" class="data row10 col4" >0.4509</td>
#       <td id="T_be70f_row10_col5" class="data row10 col5" >0.7459</td>
#     </tr>
#     <tr>
#       <th id="T_be70f_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_be70f_row11_col0" class="data row11 col0" >0.2537</td>
#       <td id="T_be70f_row11_col1" class="data row11 col1" >68.9582</td>
#       <td id="T_be70f_row11_col2" class="data row11 col2" >1.6384</td>
#       <td id="T_be70f_row11_col3" class="data row11 col3" >0.0637</td>
#       <td id="T_be70f_row11_col4" class="data row11 col4" >0.0084</td>
#       <td id="T_be70f_row11_col5" class="data row11 col5" >0.5298</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Finalize models.

final_et = finalize_model(model_et)
final_rf = finalize_model(model_rf)
final_xgboost = finalize_model(model_xgboost)
final_catboost = finalize_model(model_catboost)
final_lightgbm = finalize_model(model_lightgbm)
final_dt = finalize_model(model_dt)
# Out:
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/xgboost/data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/martin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The attribute `n_features_` is deprecated in 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Save models.

save_model(final_et, 'et_model', model_only=True);
save_model(final_rf, 'rf_model', model_only=True);
save_model(final_xgboost, 'xgboost_model', model_only=True);
save_model(final_catboost, 'catboost_model', model_only=True);
save_model(final_lightgbm, 'lightgbm_model', model_only=True);
save_model(final_dt, 'dt_model', model_only=True);
# Out:
# Transformation Pipeline and Model Succesfully Saved
# Transformation Pipeline and Model Succesfully Saved
# Transformation Pipeline and Model Succesfully Saved
# Transformation Pipeline and Model Succesfully Saved
# Finished loading model, total used 100 iterations
# Transformation Pipeline and Model Succesfully Saved
# Transformation Pipeline and Model Succesfully Saved

# %%
# Load models (i.e. testing).

final_et = load_model('et_model');
final_rf = load_model('rf_model');
final_xgboost = load_model('xgboost_model');
final_catboost = load_model('catboost_model');
final_lightgbm = load_model('lightgbm_model');
final_dt = load_model('dt_model');
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded

# %%
# Create predictions.

prediction_struct = test.drop(['Total_Load', 'lag48', 'last_day_LMP', 'month', 'day'], axis=1)

et_predictions = predict_model(final_et, data=test)[['Label']]
rf_predictions = predict_model(final_rf, data=test)[['Label']]
xgboost_predictions = predict_model(final_xgboost, data=test)[['Label']]
catboost_predictions = predict_model(final_catboost, data=test)[['Label']]
lightgbm_predictions = predict_model(final_lightgbm, data=test)[['Label']]
dt_predictions = predict_model(final_dt, data=test)[['Label']]

# %%
et_predictions.rename(columns = {'Label':'et_prediction'}, inplace = True)
rf_predictions.rename(columns = {'Label':'rf_prediction'}, inplace = True)
xgboost_predictions.rename(columns = {'Label':'xgboost_prediction'}, inplace = True)
catboost_predictions.rename(columns = {'Label':'catboost_prediction'}, inplace = True)
lightgbm_predictions.rename(columns = {'Label':'lightgbm_prediction'}, inplace = True)
dt_predictions.rename(columns = {'Label':'dt_prediction'}, inplace = True)

# %%
# Join predictions.
prediction = pd.concat([prediction_struct, et_predictions, rf_predictions, xgboost_predictions, catboost_predictions, lightgbm_predictions, dt_predictions], axis=1)
prediction
# Out:
#                      Date    LMP  et_prediction  rf_prediction  \
# 0     2021-07-03 13:00:00  23.69      23.690001      23.280000
# 1     2021-07-03 14:00:00  22.22      22.219999      22.187499
# 2     2021-07-03 15:00:00  21.47      21.469999      22.200100
# 3     2021-07-03 16:00:00  21.47      21.914900      22.698500
# 4     2021-07-03 17:00:00  21.24      21.240000      22.307400
# ...                   ...    ...            ...            ...
# 4350  2021-12-31 19:00:00  33.73      33.730000      35.564400
# 4351  2021-12-31 20:00:00  31.14      31.139999      31.878999
# 4352  2021-12-31 21:00:00  31.18      31.180000      31.297800
# 4353  2021-12-31 22:00:00  31.11      31.110001      31.201200
# 4354  2021-12-31 23:00:00  29.67      29.670000      29.399500
#
#       xgboost_prediction  catboost_prediction  lightgbm_prediction  \
# 0              17.939884            19.048744            22.738340
# 1              19.201937            20.308509            22.667917
# 2              19.436258            21.118753            23.059400
# 3              25.622854            24.698550            24.903695
# 4              24.713579            25.781150            24.982059
# ...                  ...                  ...                  ...
# 4350           33.096752            32.220376            33.939117
# 4351           32.612610            33.377874            32.059042
# 4352           29.164650            28.621501            27.599492
# 4353           26.402733            27.831569            24.676575
# 4354           24.979420            23.893628            24.164307
#
#       dt_prediction
# 0         23.690001
# 1         22.219999
# 2         21.469999
# 3         23.209999
# 4         21.240000
# ...             ...
# 4350      33.730000
# 4351      31.139999
# 4352      31.180000
# 4353      31.110001
# 4354      29.670000
#
# [4355 rows x 8 columns]

# %%
figure(figsize=(20, 10), dpi=250)

# prediction
sns.lineplot(data=prediction.iloc[315:350].drop(['LMP'], axis=1))
sns.lineplot(x=prediction.iloc[315:350].index, y='LMP', data=prediction.iloc[315:350], ci=None)
# Out:
# <AxesSubplot:ylabel='LMP'>

# %%
# Checking ET model. 

plot_model(model_et)

# %%
plot_model(model_et, plot = 'error')

# %%
plot_model(model_et, plot = 'feature')

# %%
prediction.to_csv('prediction.csv')

# %%
test = pd.read_csv('testing_per_usual.csv')
test = test.drop(['Unnamed: 0'], axis=1)
test['LMP'] = test['lag48']
test
# Out:
#                    Date  lag48  last_day_LMP  month  day  Total_Load    LMP
# 0   2022-12-06 00:00:00  38.78     44.701664     12    8       10490  38.78
# 1   2022-12-06 01:00:00  38.44     44.701664     12    8       10060  38.44
# 2   2022-12-06 02:00:00  36.94     44.701664     12    8        9920  36.94
# 3   2022-12-06 03:00:00  37.78     44.701664     12    8        9890  37.78
# 4   2022-12-06 04:00:00  34.46     44.701664     12    8       10220  34.46
# 5   2022-12-06 05:00:00  34.00     44.701664     12    8       11110  34.00
# 6   2022-12-06 06:00:00  41.15     44.701664     12    8       12770  41.15
# 7   2022-12-06 07:00:00  40.85     44.701664     12    8       13320  40.85
# 8   2022-12-06 08:00:00  52.23     44.701664     12    8       13000  52.23
# 9   2022-12-06 09:00:00  46.28     44.701664     12    8       12500  46.28
# 10  2022-12-06 10:00:00  37.52     44.701664     12    8       12010  37.52
# 11  2022-12-06 11:00:00  36.74     44.701664     12    8       11890  36.74
# 12  2022-12-06 12:00:00  37.30     44.701664     12    8       11980  37.30
# 13  2022-12-06 13:00:00  43.49     44.701664     12    8       12170  43.49
# 14  2022-12-06 14:00:00  47.28     44.701664     12    8       12850  47.28
# 15  2022-12-06 15:00:00  43.15     44.701664     12    8       13610  43.15
# 16  2022-12-06 16:00:00  55.23     44.701664     12    8       15010  55.23
# 17  2022-12-06 17:00:00  58.67     44.701664     12    8       15760  58.67
# 18  2022-12-06 18:00:00  50.42     44.701664     12    8       15670  50.42
# 19  2022-12-06 19:00:00  43.36     44.701664     12    8       15260  43.36
# 20  2022-12-06 20:00:00  50.83     44.701664     12    8       14660  50.83
# 21  2022-12-06 21:00:00  43.60     44.701664     12    8       13880  43.60
# 22  2022-12-06 22:00:00  64.36     44.701664     12    8       12890  64.36
# 23  2022-12-06 23:00:00  59.98     44.701664     12    8       11960  59.98

# %%
setup = setup(data = test, target = 'LMP', fold_shuffle=True)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            23:39:36
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                 Data Type
# Date                 Date
# lag48             Numeric
# last_day_LMP      Numeric
# month         Categorical
# day           Categorical
# Total_Load    Categorical
# LMP                 Label
# quit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Read the documentation of setup to learn how to overwrite data types over the inferred types. setup function must run again before you continue modeling.

# %%
final_et = load_model('et_model');
final_rf = load_model('rf_model');
final_xgboost = load_model('xgboost_model');
final_catboost = load_model('catboost_model');
final_lightgbm = load_model('lightgbm_model');
final_dt = load_model('dt_model');
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded
# Transformation Pipeline and Model Successfully Loaded

# %%
# prediction_struct = test.drop(['Total_Load', 'lag48', 'last_day_LMP', 'month', 'day'], axis=1)

et_predictions = predict_model(final_et, data=test)[['Label']]
rf_predictions = predict_model(final_rf, data=test)[['Label']]
xgboost_predictions = predict_model(final_xgboost, data=test)[['Label']]
catboost_predictions = predict_model(final_catboost, data=test)[['Label']]
lightgbm_predictions = predict_model(final_lightgbm, data=test)[['Label']]
dt_predictions = predict_model(final_dt, data=test)[['Label']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 3>()
#       1 # prediction_struct = test.drop(['Total_Load', 'lag48', 'last_day_LMP', 'month', 'day'], axis=1)
# ----> 3 et_predictions = predict_model(final_et, data=test)[['Label']]
#       4 rf_predictions = predict_model(final_rf, data=test)[['Label']]
#       5 xgboost_predictions = predict_model(final_xgboost, data=test)[['Label']]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/regression.py:1693, in predict_model(estimator, data, round, verbose)
#    1639 def predict_model(
#    1640     estimator,
#    1641     data: Optional[pd.DataFrame] = None,
#    1642     round: int = 4,
#    1643     verbose: bool = True,
#    1644 ) -> pd.DataFrame:
#    1646     """
#    1647     This function predicts ``Label`` using a trained model. When ``data`` is
#    1648     None, it predicts label on the holdout set.
#    (...)
#    1690
#    1691     """
# -> 1693     return pycaret.internal.tabular.predict_model(
#    1694         estimator=estimator,
#    1695         data=data,
#    1696         probability_threshold=None,
#    1697         encoded_labels=True,
#    1698         round=round,
#    1699         verbose=verbose,
#    1700         ml_usecase=MLUsecase.REGRESSION,
#    1701     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pycaret/internal/tabular.py:8346, in predict_model(estimator, data, probability_threshold, encoded_labels, round, verbose, ml_usecase, display)
#    8342         label_column.replace(replacement_mapper, inplace=True)
#    8344 # prediction starts here
# -> 8346 pred = np.nan_to_num(estimator.predict(X_test_))
#    8348 try:
#    8349     score = estimator.predict_proba(X_test_)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/metaestimators.py:113, in _AvailableIfDescriptor.__get__.<locals>.<lambda>(*args, **kwargs)
#     110         raise attr_err
#     112     # lambda, but not partial, allows help() to work with update_wrapper
# --> 113     out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114 else:
#     116     def fn(*args, **kwargs):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py:470, in Pipeline.predict(self, X, **predict_params)
#     468 for _, name, transform in self._iter(with_final=False):
#     469     Xt = transform.transform(Xt)
# --> 470 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:971, in ForestRegressor.predict(self, X)
#     969 check_is_fitted(self)
#     970 # Check data
# --> 971 X = self._validate_X_predict(X)
#     973 # Assign chunk of trees to jobs
#     974 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:579, in BaseForest._validate_X_predict(self, X)
#     576 """
#     577 Validate X whenever one tries to predict, apply, predict_proba."""
#     578 check_is_fitted(self)
# --> 579 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     580 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     581     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 24 features, but ExtraTreesRegressor is expecting 49 features as input.

# %%
et_predictions.rename(columns = {'Label':'et'}, inplace = True)
rf_predictions.rename(columns = {'Label':'rf'}, inplace = True)
xgboost_predictions.rename(columns = {'Label':'xgboost'}, inplace = True)
catboost_predictions.rename(columns = {'Label':'catboost'}, inplace = True)
lightgbm_predictions.rename(columns = {'Label':'lightgbm'}, inplace = True)
dt_predictions.rename(columns = {'Label':'dt'}, inplace = True)

# %%
prediction = pd.concat([et_predictions, rf_predictions, xgboost_predictions, catboost_predictions, lightgbm_predictions, dt_predictions], axis=1)
prediction
